# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
#!unzip processed_celeba_small.zip

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    # TODO: Implement function and return a dataloader
    
    train_transforms   = transforms.Compose([transforms.Resize(image_size),
                                         transforms.ToTensor()])  
    facegen_train_data = datasets.ImageFolder(root=data_dir, transform=train_transforms)
    dataloader      = torch.utils.data.DataLoader(facegen_train_data, batch_size, shuffle=True)
    
    return dataloader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 32
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    min, max = feature_range
    x = x*(max - min) + min
    
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.9686)
# Max:  tensor(0.7882)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
def conv(input_channels, output_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Creates a convolutional layer, with optional batch normalization.
    """
    layers = []
    conv_layer = nn.Conv2d(input_channels, output_channels, 
                           kernel_size, stride, padding, bias=False)
    
    # append conv layer
    layers.append(conv_layer)

    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(output_channels))
     
    # using Sequential container
    return nn.Sequential(*layers)

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim=32):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()
        self.conv_dim = conv_dim
        # Convolutional layers
        self.conv1 = conv(3, conv_dim*4*4, 4, batch_norm=False) # output feature size is 16x16
        self.conv2 = conv(conv_dim*4*4, conv_dim*4*4*2, 4, batch_norm= True) # output feature size is 8x8
        self.conv3 = conv(conv_dim*4*4*2, conv_dim*4*4*4, 4, batch_norm=True) # output feature size is 4x4
        #self.conv4 = conv(conv_dim*4*4*4, conv_dim*4*4*4*2, 4, batch_norm=True) #output feature size is 2x2        
        # Fully Connected
        self.fc = nn.Linear(conv_dim*4*4*4*4*4,1)
        # dropout layer
        self.dropout = nn.Dropout(0.2)


    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        
        x = F.leaky_relu(self.conv1(x), 0.2)
        x = F.leaky_relu(self.conv2(x), 0.2)
        x = F.leaky_relu(self.conv3(x), 0.2)
       # x = F.leaky_relu(self.conv4(x), 0.2)
        x = self.dropout(x)
        x = x.view(-1, self.conv_dim*4*4*4*4*4)
        x = self.fc(x)
        
        return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
def deconv(input_channels, output_channels, kernel_size, stride=2, padding=1, batch_norm=True):

    layers = []
    deconv_layer = nn.ConvTranspose2d(input_channels, output_channels, kernel_size,
                                      stride, padding, bias=False)
    layers.append(deconv_layer)
    
    if batch_norm:
        layers.append(nn.BatchNorm2d(output_channels))
                
    return nn.Sequential(*layers)

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim
        
        # Defining the layers
     #   self.fc1     = nn.Linear(z_size, conv_dim*4*4*4*2*2*2) 
        # Transpose convolutional layers
      #  self.t_conv1 = deconv(conv_dim*4*4*4*2, conv_dim*4*4*4, 4)
       # self.t_conv2 = deconv(conv_dim*4*4*4, conv_dim*4*4*2, 4)
        #self.t_conv3 = deconv(conv_dim*4*4*2, conv_dim*4*4, 4)
        #self.t_conv4 = deconv(conv_dim*4*4, 3, 4, batch_norm=False)
        
            
        # Defining the layers
        self.fc1     = nn.Linear(z_size, conv_dim*4*4*4*4*4) 
        # Transpose convolutional layers
        self.t_conv1 = deconv(conv_dim*4*4*4, conv_dim*4*4*2, 4)
        self.t_conv2 = deconv(conv_dim*4*4*2, conv_dim*4*4, 4)
        self.t_conv3 = deconv(conv_dim*4*4, 3, 4, batch_norm=False)
             
        self.dropout = nn.Dropout(0.2)

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        x = self.fc1(x)
        x = F.relu(x)
        
        x = x.view(-1, self.conv_dim*4*4*4, 4, 4)
        
        x = F.relu(self.t_conv1(x)) # output 8x8
        x = self.dropout(x)
        x = F.relu(self.t_conv2(x)) # output 16x16
        x = self.dropout(x)
        x = self.t_conv3(x) # output 32x32

        
        x = F.tanh(x)
        return x

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    
    # TODO: Apply initial weights to convolutional and linear layers
    if (classname.find('Conv') != -1 or classname.find('Linear') != -1 or classname.find('BatchNorm2d') != -1):
        # apply a uniform distribution to the weights and a bias=0
        m.weight.data.normal_(0.0, 0.02)
      #  m.bias.data.fill_(0)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 32
g_conv_dim = 32
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(512, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(1024, 2048, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=32768, out_features=1, bias=True)
#   (dropout): Dropout(p=0.2)
# )
#
# Generator(
#   (fc1): Linear(in_features=100, out_features=32768, bias=True)
#   (t_conv1): Sequential(
#     (0): ConvTranspose2d(2048, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv2): Sequential(
#     (0): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv3): Sequential(
#     (0): ConvTranspose2d(512, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (dropout): Dropout(p=0.2)
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    batch_size = D_out.size(0)
    labels     = torch.ones(batch_size)*0.9 # smooth labels
    if train_on_gpu:
        labels = labels.cuda()
    
    criterion  = nn.BCEWithLogitsLoss()
    loss       = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    batch_size = D_out.size(0)
    labels     = torch.zeros(batch_size)
    if train_on_gpu:
        labels = labels.cuda()
    
    criterion  = nn.BCEWithLogitsLoss()
    loss       = criterion(D_out.squeeze(), labels)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

# params
lr = 0.0002
beta1=0.2
beta2=0.09 # default value

# Create optimizers for the discriminator and generator
d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
from workspace_utils import active_session
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    with active_session():
        for epoch in range(n_epochs):

            # batch training loop
            for batch_i, (real_images, _) in enumerate(celeba_train_loader):

                batch_size = real_images.size(0)
                real_images = scale(real_images)

                # ===============================================
                #         YOUR CODE HERE: TRAIN THE NETWORKS
                # ===============================================

                d_optimizer.zero_grad()

                # 1. Train the discriminator on real and fake images
                if train_on_gpu:
                    real_images = real_images.cuda()

                D_real      = D(real_images)
                d_real_loss = real_loss(D_real)

                # Generate fake images
                fake_images = G(fixed_z)

                # Calculate fake loss
                D_fake      = D(fake_images)
                d_fake_loss = fake_loss(D_fake)

                # Total discriminator loss
                d_loss = d_real_loss + d_fake_loss

                # Back Propagation for discriminator
                d_loss.backward()
                d_optimizer.step()

                # 2. Train the generator with an adversarial loss

                g_optimizer.zero_grad()
                #Generate a set of fake images for generator training
                z = np.random.uniform(-1, 1, size=(batch_size, z_size))
                z = torch.from_numpy(z).float()
                if train_on_gpu:
                    z = z.cuda()
                fake_images = G(z)

                # Discriminator loss to be used to calculate generator loss
                D_fake = D(fake_images)
                g_loss = real_loss(D_fake)

                # Back propagation
                g_loss.backward()
                g_optimizer.step()

                # ===============================================
                #              END OF YOUR CODE
                # ===============================================

                # Print some loss stats
                if batch_i % print_every == 0:
                    # append discriminator loss and generator loss
                    losses.append((d_loss.item(), g_loss.item()))
                    # print discriminator and generator loss
                    print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                            epoch+1, n_epochs, d_loss.item(), g_loss.item()))


            ## AFTER EACH EPOCH##    
            # this code assumes your generator is named G, feel free to change the name
            # generate and save sample, fake images
            G.eval() # for generating samples
            samples_z = G(fixed_z)
            samples.append(samples_z)
            G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 10


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   10] | d_loss: 1.3857 | g_loss: 0.8654
# Epoch [    1/   10] | d_loss: 0.5171 | g_loss: 3.9008
# Epoch [    1/   10] | d_loss: 0.6132 | g_loss: 3.9590
# Epoch [    1/   10] | d_loss: 1.6262 | g_loss: 3.5059
# Epoch [    1/   10] | d_loss: 0.9563 | g_loss: 3.5711
# Epoch [    1/   10] | d_loss: 0.8793 | g_loss: 3.2720
# Epoch [    1/   10] | d_loss: 0.5734 | g_loss: 2.0335
# Epoch [    1/   10] | d_loss: 0.6132 | g_loss: 2.1802
# Epoch [    1/   10] | d_loss: 1.0232 | g_loss: 2.1815
# Epoch [    1/   10] | d_loss: 0.8099 | g_loss: 2.6484
# Epoch [    1/   10] | d_loss: 0.6774 | g_loss: 0.5487
# Epoch [    1/   10] | d_loss: 0.7185 | g_loss: 0.6974
# Epoch [    1/   10] | d_loss: 0.9806 | g_loss: 1.0970
# Epoch [    1/   10] | d_loss: 0.7740 | g_loss: 0.6407
# Epoch [    1/   10] | d_loss: 0.7585 | g_loss: 0.8151
# Epoch [    1/   10] | d_loss: 0.5972 | g_loss: 0.3664
# Epoch [    1/   10] | d_loss: 0.8997 | g_loss: 0.5083
# Epoch [    1/   10] | d_loss: 0.5686 | g_loss: 0.3589
# Epoch [    1/   10] | d_loss: 0.4008 | g_loss: 0.3837
# Epoch [    1/   10] | d_loss: 0.4322 | g_loss: 0.4009
# Epoch [    1/   10] | d_loss: 0.4750 | g_loss: 0.3526
# Epoch [    1/   10] | d_loss: 0.4563 | g_loss: 0.3701
# Epoch [    1/   10] | d_loss: 0.5426 | g_loss: 0.3395
# Epoch [    1/   10] | d_loss: 0.5321 | g_loss: 0.3356
# Epoch [    1/   10] | d_loss: 0.5634 | g_loss: 0.3318
# Epoch [    1/   10] | d_loss: 0.4572 | g_loss: 0.3858
# Epoch [    1/   10] | d_loss: 0.3698 | g_loss: 0.3471
# Epoch [    1/   10] | d_loss: 0.4673 | g_loss: 0.3743
# Epoch [    1/   10] | d_loss: 0.4401 | g_loss: 0.3539
# Epoch [    1/   10] | d_loss: 0.3698 | g_loss: 0.3416
# Epoch [    1/   10] | d_loss: 0.5235 | g_loss: 0.3833
# Epoch [    1/   10] | d_loss: 0.3687 | g_loss: 0.4896
# Epoch [    1/   10] | d_loss: 0.4166 | g_loss: 0.3348
# Epoch [    1/   10] | d_loss: 0.3657 | g_loss: 0.3698
# Epoch [    1/   10] | d_loss: 0.3602 | g_loss: 0.4861
# Epoch [    1/   10] | d_loss: 0.3776 | g_loss: 0.3541
# Epoch [    1/   10] | d_loss: 0.4286 | g_loss: 0.3537
# Epoch [    1/   10] | d_loss: 0.4262 | g_loss: 0.4163
# Epoch [    1/   10] | d_loss: 0.3761 | g_loss: 0.3483
# Epoch [    1/   10] | d_loss: 0.4001 | g_loss: 0.3481
# Epoch [    1/   10] | d_loss: 0.3579 | g_loss: 0.3365
# Epoch [    1/   10] | d_loss: 0.4212 | g_loss: 0.3400
# Epoch [    1/   10] | d_loss: 0.5187 | g_loss: 0.3752
# Epoch [    1/   10] | d_loss: 0.5136 | g_loss: 0.3320
# Epoch [    1/   10] | d_loss: 0.4231 | g_loss: 0.4508
# Epoch [    1/   10] | d_loss: 0.4112 | g_loss: 0.3725
# Epoch [    1/   10] | d_loss: 0.4982 | g_loss: 0.3320
# Epoch [    1/   10] | d_loss: 0.4166 | g_loss: 0.3437
# Epoch [    1/   10] | d_loss: 0.4948 | g_loss: 0.4725
# Epoch [    1/   10] | d_loss: 0.3875 | g_loss: 0.3442
# Epoch [    1/   10] | d_loss: 0.5704 | g_loss: 0.3522
# Epoch [    1/   10] | d_loss: 0.3661 | g_loss: 0.3386
# Epoch [    1/   10] | d_loss: 0.6521 | g_loss: 0.3379
# Epoch [    1/   10] | d_loss: 0.4706 | g_loss: 0.4047
# Epoch [    1/   10] | d_loss: 0.4101 | g_loss: 0.3363
# Epoch [    1/   10] | d_loss: 0.3706 | g_loss: 0.3471
# Epoch [    1/   10] | d_loss: 0.4699 | g_loss: 0.3362
# Epoch [    2/   10] | d_loss: 0.3818 | g_loss: 0.3314
# Epoch [    2/   10] | d_loss: 0.4624 | g_loss: 0.3555
# Epoch [    2/   10] | d_loss: 0.4731 | g_loss: 0.3630
# Epoch [    2/   10] | d_loss: 0.8347 | g_loss: 0.3358
# Epoch [    2/   10] | d_loss: 0.3421 | g_loss: 0.3777
# Epoch [    2/   10] | d_loss: 0.4100 | g_loss: 0.3784
# Epoch [    2/   10] | d_loss: 0.4588 | g_loss: 0.3791
# Epoch [    2/   10] | d_loss: 0.3409 | g_loss: 0.3349
# Epoch [    2/   10] | d_loss: 0.4122 | g_loss: 0.3644
# Epoch [    2/   10] | d_loss: 0.5472 | g_loss: 0.3685
# Epoch [    2/   10] | d_loss: 0.3642 | g_loss: 0.3363
# Epoch [    2/   10] | d_loss: 0.3594 | g_loss: 0.3689
# Epoch [    2/   10] | d_loss: 0.3990 | g_loss: 0.3720
# Epoch [    2/   10] | d_loss: 0.4132 | g_loss: 0.3587
# Epoch [    2/   10] | d_loss: 0.3880 | g_loss: 0.3300
# Epoch [    2/   10] | d_loss: 0.3624 | g_loss: 0.3378
# Epoch [    2/   10] | d_loss: 0.3997 | g_loss: 0.3486
# Epoch [    2/   10] | d_loss: 0.3458 | g_loss: 0.5660
# Epoch [    2/   10] | d_loss: 0.3545 | g_loss: 0.3847
# Epoch [    2/   10] | d_loss: 0.4302 | g_loss: 0.4010
# Epoch [    2/   10] | d_loss: 0.3623 | g_loss: 0.3624
# Epoch [    2/   10] | d_loss: 0.3748 | g_loss: 0.3873
# Epoch [    2/   10] | d_loss: 0.3637 | g_loss: 0.3715
# Epoch [    2/   10] | d_loss: 0.4442 | g_loss: 0.3903
# Epoch [    2/   10] | d_loss: 0.4608 | g_loss: 0.3966
# Epoch [    2/   10] | d_loss: 0.4082 | g_loss: 0.3352
# Epoch [    2/   10] | d_loss: 0.3619 | g_loss: 0.3493
# Epoch [    2/   10] | d_loss: 0.3741 | g_loss: 0.3939
# Epoch [    2/   10] | d_loss: 0.3458 | g_loss: 0.5845
# Epoch [    2/   10] | d_loss: 0.4005 | g_loss: 0.3802
# Epoch [    2/   10] | d_loss: 0.5859 | g_loss: 0.3332
# Epoch [    2/   10] | d_loss: 0.4081 | g_loss: 0.3621
# Epoch [    2/   10] | d_loss: 0.3453 | g_loss: 0.3948
# Epoch [    2/   10] | d_loss: 0.4019 | g_loss: 0.3587
# Epoch [    2/   10] | d_loss: 0.3857 | g_loss: 0.3313
# Epoch [    2/   10] | d_loss: 0.4082 | g_loss: 0.3328
# Epoch [    2/   10] | d_loss: 0.3549 | g_loss: 0.3395
# Epoch [    2/   10] | d_loss: 0.3752 | g_loss: 0.4001
# Epoch [    2/   10] | d_loss: 0.3799 | g_loss: 0.3347
# Epoch [    2/   10] | d_loss: 0.3719 | g_loss: 0.3585
# Epoch [    2/   10] | d_loss: 0.4455 | g_loss: 0.3328
# Epoch [    2/   10] | d_loss: 0.3581 | g_loss: 0.3680
# Epoch [    2/   10] | d_loss: 0.4625 | g_loss: 0.3371
# Epoch [    2/   10] | d_loss: 0.3418 | g_loss: 0.3483
# Epoch [    2/   10] | d_loss: 0.3593 | g_loss: 0.3347
# Epoch [    2/   10] | d_loss: 0.3379 | g_loss: 0.3623
# Epoch [    2/   10] | d_loss: 0.3538 | g_loss: 0.3513
# Epoch [    2/   10] | d_loss: 0.3699 | g_loss: 0.3984
# Epoch [    2/   10] | d_loss: 0.3456 | g_loss: 0.3328
# Epoch [    2/   10] | d_loss: 0.3644 | g_loss: 0.3962
# Epoch [    2/   10] | d_loss: 0.3446 | g_loss: 0.3508
# Epoch [    2/   10] | d_loss: 0.3407 | g_loss: 0.3330
# Epoch [    2/   10] | d_loss: 0.3466 | g_loss: 0.3440
# Epoch [    2/   10] | d_loss: 0.3522 | g_loss: 0.3694
# Epoch [    2/   10] | d_loss: 0.3488 | g_loss: 0.4273
# Epoch [    2/   10] | d_loss: 0.3450 | g_loss: 0.3605
# Epoch [    2/   10] | d_loss: 0.3381 | g_loss: 0.3286
# Epoch [    3/   10] | d_loss: 0.4260 | g_loss: 0.3347
# Epoch [    3/   10] | d_loss: 0.3635 | g_loss: 0.3432
# Epoch [    3/   10] | d_loss: 0.3766 | g_loss: 0.3351
# Epoch [    3/   10] | d_loss: 0.3744 | g_loss: 0.3388
# Epoch [    3/   10] | d_loss: 0.3634 | g_loss: 0.3361
# Epoch [    3/   10] | d_loss: 0.3547 | g_loss: 0.3279
# Epoch [    3/   10] | d_loss: 0.3881 | g_loss: 0.3310
# Epoch [    3/   10] | d_loss: 0.4948 | g_loss: 0.3274
# Epoch [    3/   10] | d_loss: 0.3741 | g_loss: 0.3328
# Epoch [    3/   10] | d_loss: 0.3400 | g_loss: 0.3332
# Epoch [    3/   10] | d_loss: 0.3400 | g_loss: 0.3346
# Epoch [    3/   10] | d_loss: 0.3369 | g_loss: 0.3521
# Epoch [    3/   10] | d_loss: 0.3463 | g_loss: 0.3278
# Epoch [    3/   10] | d_loss: 0.3419 | g_loss: 0.3277
# Epoch [    3/   10] | d_loss: 0.3517 | g_loss: 0.3333
# Epoch [    3/   10] | d_loss: 0.3375 | g_loss: 0.3330
# Epoch [    3/   10] | d_loss: 0.3886 | g_loss: 0.3277
# Epoch [    3/   10] | d_loss: 0.3508 | g_loss: 0.3621
# Epoch [    3/   10] | d_loss: 0.3762 | g_loss: 0.3302
# Epoch [    3/   10] | d_loss: 0.3491 | g_loss: 0.4290
# Epoch [    3/   10] | d_loss: 0.3478 | g_loss: 0.3284
# Epoch [    3/   10] | d_loss: 0.3389 | g_loss: 0.3301
# Epoch [    3/   10] | d_loss: 0.5654 | g_loss: 0.3332
# Epoch [    3/   10] | d_loss: 0.3387 | g_loss: 0.3318
# Epoch [    3/   10] | d_loss: 0.3555 | g_loss: 0.3379
# Epoch [    3/   10] | d_loss: 0.3350 | g_loss: 0.3292
# Epoch [    3/   10] | d_loss: 0.3519 | g_loss: 0.3268
# Epoch [    3/   10] | d_loss: 0.3319 | g_loss: 0.3315
# Epoch [    3/   10] | d_loss: 0.3590 | g_loss: 0.3457
# Epoch [    3/   10] | d_loss: 0.3374 | g_loss: 0.3307
# Epoch [    3/   10] | d_loss: 0.3409 | g_loss: 0.3573
# Epoch [    3/   10] | d_loss: 0.3469 | g_loss: 0.3311
# Epoch [    3/   10] | d_loss: 0.3759 | g_loss: 0.3324
# Epoch [    3/   10] | d_loss: 0.3524 | g_loss: 0.3573
# Epoch [    3/   10] | d_loss: 0.3965 | g_loss: 0.3328
# Epoch [    3/   10] | d_loss: 0.4296 | g_loss: 0.3866
# Epoch [    3/   10] | d_loss: 0.3651 | g_loss: 0.3388
# Epoch [    3/   10] | d_loss: 0.3597 | g_loss: 0.3754
# Epoch [    3/   10] | d_loss: 0.3884 | g_loss: 0.3748
# Epoch [    3/   10] | d_loss: 0.3847 | g_loss: 0.3291
# Epoch [    3/   10] | d_loss: 0.3630 | g_loss: 0.3524
# Epoch [    3/   10] | d_loss: 0.3900 | g_loss: 0.3310
# Epoch [    3/   10] | d_loss: 0.3422 | g_loss: 0.3292
# Epoch [    3/   10] | d_loss: 0.3406 | g_loss: 0.3266
# Epoch [    3/   10] | d_loss: 0.3827 | g_loss: 0.3315
# Epoch [    3/   10] | d_loss: 0.3849 | g_loss: 0.3313
# Epoch [    3/   10] | d_loss: 0.3423 | g_loss: 0.3478
# Epoch [    3/   10] | d_loss: 0.3362 | g_loss: 0.3500
# Epoch [    3/   10] | d_loss: 0.3332 | g_loss: 0.3439
# Epoch [    3/   10] | d_loss: 0.3406 | g_loss: 0.4123
# Epoch [    3/   10] | d_loss: 0.4354 | g_loss: 0.4484
# Epoch [    3/   10] | d_loss: 0.3311 | g_loss: 0.6223
# Epoch [    3/   10] | d_loss: 0.3302 | g_loss: 0.4915
# Epoch [    3/   10] | d_loss: 0.3803 | g_loss: 0.3892
# Epoch [    3/   10] | d_loss: 0.3551 | g_loss: 0.6331
# Epoch [    3/   10] | d_loss: 0.3516 | g_loss: 1.5252
# Epoch [    3/   10] | d_loss: 0.3376 | g_loss: 1.6578
# Epoch [    4/   10] | d_loss: 0.3476 | g_loss: 1.5390
# Epoch [    4/   10] | d_loss: 0.3284 | g_loss: 1.8712
# Epoch [    4/   10] | d_loss: 0.3296 | g_loss: 3.4158
# Epoch [    4/   10] | d_loss: 0.3689 | g_loss: 2.0161
# Epoch [    4/   10] | d_loss: 0.4020 | g_loss: 1.1101
# Epoch [    4/   10] | d_loss: 0.3363 | g_loss: 0.8284
# Epoch [    4/   10] | d_loss: 0.3400 | g_loss: 0.4263
# Epoch [    4/   10] | d_loss: 0.3717 | g_loss: 0.4540
# Epoch [    4/   10] | d_loss: 0.4764 | g_loss: 0.3959
# Epoch [    4/   10] | d_loss: 0.3541 | g_loss: 0.3362
# Epoch [    4/   10] | d_loss: 0.3477 | g_loss: 0.4164
# Epoch [    4/   10] | d_loss: 0.3483 | g_loss: 0.5404
# Epoch [    4/   10] | d_loss: 0.3686 | g_loss: 0.3705
# Epoch [    4/   10] | d_loss: 0.5842 | g_loss: 0.3589
# Epoch [    4/   10] | d_loss: 0.3357 | g_loss: 0.4706
# Epoch [    4/   10] | d_loss: 0.3483 | g_loss: 0.4920
# Epoch [    4/   10] | d_loss: 0.3389 | g_loss: 0.5576
# Epoch [    4/   10] | d_loss: 0.3440 | g_loss: 0.3358
# Epoch [    4/   10] | d_loss: 0.3653 | g_loss: 0.4615
# Epoch [    4/   10] | d_loss: 0.4231 | g_loss: 0.4673
# Epoch [    4/   10] | d_loss: 0.3882 | g_loss: 0.5375
# Epoch [    4/   10] | d_loss: 0.4789 | g_loss: 0.3399
# Epoch [    4/   10] | d_loss: 0.3442 | g_loss: 0.3305
# Epoch [    4/   10] | d_loss: 0.3467 | g_loss: 0.3451
# Epoch [    4/   10] | d_loss: 0.3445 | g_loss: 0.3289
# Epoch [    4/   10] | d_loss: 0.3560 | g_loss: 0.3285
# Epoch [    4/   10] | d_loss: 0.3874 | g_loss: 0.3653
# Epoch [    4/   10] | d_loss: 0.3322 | g_loss: 0.3498
# Epoch [    4/   10] | d_loss: 0.3628 | g_loss: 0.3690
# Epoch [    4/   10] | d_loss: 0.3339 | g_loss: 0.3426
# Epoch [    4/   10] | d_loss: 0.3890 | g_loss: 0.3277
# Epoch [    4/   10] | d_loss: 0.3494 | g_loss: 0.3572
# Epoch [    4/   10] | d_loss: 0.3329 | g_loss: 0.3262
# Epoch [    4/   10] | d_loss: 0.3466 | g_loss: 0.4074
# Epoch [    4/   10] | d_loss: 0.3437 | g_loss: 0.3300
# Epoch [    4/   10] | d_loss: 0.3367 | g_loss: 0.3506
# Epoch [    4/   10] | d_loss: 0.3308 | g_loss: 0.3922
# Epoch [    4/   10] | d_loss: 0.3411 | g_loss: 0.3442
# Epoch [    4/   10] | d_loss: 0.3398 | g_loss: 0.3352
# Epoch [    4/   10] | d_loss: 0.3888 | g_loss: 0.3336
# Epoch [    4/   10] | d_loss: 0.3508 | g_loss: 0.3590
# Epoch [    4/   10] | d_loss: 0.3383 | g_loss: 0.3496
# Epoch [    4/   10] | d_loss: 0.3407 | g_loss: 0.3298
# Epoch [    4/   10] | d_loss: 0.3779 | g_loss: 0.4410
# Epoch [    4/   10] | d_loss: 0.3302 | g_loss: 0.3355
# Epoch [    4/   10] | d_loss: 0.3372 | g_loss: 0.3515
# Epoch [    4/   10] | d_loss: 0.3365 | g_loss: 0.3485
# Epoch [    4/   10] | d_loss: 0.3287 | g_loss: 0.3629
# Epoch [    4/   10] | d_loss: 0.3285 | g_loss: 0.5290
# Epoch [    4/   10] | d_loss: 0.3372 | g_loss: 0.3542
# Epoch [    4/   10] | d_loss: 0.3285 | g_loss: 0.3451
# Epoch [    4/   10] | d_loss: 0.3449 | g_loss: 0.4425
# Epoch [    4/   10] | d_loss: 0.3289 | g_loss: 1.0354
# Epoch [    4/   10] | d_loss: 0.3362 | g_loss: 0.6234
# Epoch [    4/   10] | d_loss: 0.3365 | g_loss: 0.4074
# Epoch [    4/   10] | d_loss: 0.3336 | g_loss: 0.4382
# Epoch [    4/   10] | d_loss: 0.3658 | g_loss: 0.3650
# Epoch [    5/   10] | d_loss: 0.3277 | g_loss: 0.3454
# Epoch [    5/   10] | d_loss: 0.3283 | g_loss: 0.3465
# Epoch [    5/   10] | d_loss: 0.3273 | g_loss: 0.3881
# Epoch [    5/   10] | d_loss: 0.3269 | g_loss: 0.4046
# Epoch [    5/   10] | d_loss: 0.3361 | g_loss: 0.3380
# Epoch [    5/   10] | d_loss: 0.3316 | g_loss: 0.5984
# Epoch [    5/   10] | d_loss: 0.3321 | g_loss: 0.5981
# Epoch [    5/   10] | d_loss: 0.3268 | g_loss: 0.4740
# Epoch [    5/   10] | d_loss: 0.3294 | g_loss: 0.5068
# Epoch [    5/   10] | d_loss: 0.3279 | g_loss: 0.6789
# Epoch [    5/   10] | d_loss: 0.3274 | g_loss: 0.8944
# Epoch [    5/   10] | d_loss: 0.3274 | g_loss: 2.7170
# Epoch [    5/   10] | d_loss: 0.3266 | g_loss: 1.5871
# Epoch [    5/   10] | d_loss: 0.3264 | g_loss: 1.5208
# Epoch [    5/   10] | d_loss: 0.3263 | g_loss: 1.6808
# Epoch [    5/   10] | d_loss: 0.3261 | g_loss: 2.0894
# Epoch [    5/   10] | d_loss: 0.3330 | g_loss: 0.7550
# Epoch [    5/   10] | d_loss: 0.3282 | g_loss: 2.3401
# Epoch [    5/   10] | d_loss: 0.3281 | g_loss: 2.4132
# Epoch [    5/   10] | d_loss: 0.3297 | g_loss: 2.7509
# Epoch [    5/   10] | d_loss: 0.3298 | g_loss: 1.5431
# Epoch [    5/   10] | d_loss: 0.3262 | g_loss: 1.6048
# Epoch [    5/   10] | d_loss: 0.3269 | g_loss: 1.6588
# Epoch [    5/   10] | d_loss: 0.3259 | g_loss: 1.5279
# Epoch [    5/   10] | d_loss: 0.3288 | g_loss: 1.2748
# Epoch [    5/   10] | d_loss: 0.3280 | g_loss: 0.8995
# Epoch [    5/   10] | d_loss: 0.3263 | g_loss: 2.1559
# Epoch [    5/   10] | d_loss: 0.3261 | g_loss: 1.8730
# Epoch [    5/   10] | d_loss: 0.3280 | g_loss: 1.1916
# Epoch [    5/   10] | d_loss: 0.3262 | g_loss: 1.0724
# Epoch [    5/   10] | d_loss: 0.3264 | g_loss: 1.3270
# Epoch [    5/   10] | d_loss: 0.3258 | g_loss: 1.0504
# Epoch [    5/   10] | d_loss: 0.3274 | g_loss: 1.3290
# Epoch [    5/   10] | d_loss: 0.3262 | g_loss: 1.6399
# Epoch [    5/   10] | d_loss: 0.3264 | g_loss: 2.9000
# Epoch [    5/   10] | d_loss: 0.3256 | g_loss: 0.3794
# Epoch [    5/   10] | d_loss: 0.3259 | g_loss: 0.3258
# Epoch [    5/   10] | d_loss: 0.3266 | g_loss: 0.3270
# Epoch [    5/   10] | d_loss: 0.3321 | g_loss: 2.1366
# Epoch [    5/   10] | d_loss: 0.3799 | g_loss: 0.4146
# Epoch [    5/   10] | d_loss: 0.3265 | g_loss: 0.3372
# Epoch [    5/   10] | d_loss: 0.3293 | g_loss: 0.3448
# Epoch [    5/   10] | d_loss: 0.3369 | g_loss: 0.3944
# Epoch [    5/   10] | d_loss: 0.3289 | g_loss: 0.4246
# Epoch [    5/   10] | d_loss: 0.3319 | g_loss: 0.3834
# Epoch [    5/   10] | d_loss: 0.3305 | g_loss: 0.7642
# Epoch [    5/   10] | d_loss: 0.3720 | g_loss: 1.3264
# Epoch [    5/   10] | d_loss: 0.3351 | g_loss: 2.2348
# Epoch [    5/   10] | d_loss: 0.3311 | g_loss: 3.6338
# Epoch [    5/   10] | d_loss: 0.3509 | g_loss: 0.5282
# Epoch [    5/   10] | d_loss: 0.3298 | g_loss: 0.7854
# Epoch [    5/   10] | d_loss: 0.3429 | g_loss: 0.6160
# Epoch [    5/   10] | d_loss: 0.3297 | g_loss: 0.3306
# Epoch [    5/   10] | d_loss: 0.3306 | g_loss: 0.3627
# Epoch [    5/   10] | d_loss: 0.4301 | g_loss: 0.4996
# Epoch [    5/   10] | d_loss: 0.3477 | g_loss: 0.6728
# Epoch [    5/   10] | d_loss: 0.3344 | g_loss: 1.0921
# Epoch [    6/   10] | d_loss: 0.3374 | g_loss: 0.4582
# Epoch [    6/   10] | d_loss: 0.3383 | g_loss: 0.3803
# Epoch [    6/   10] | d_loss: 0.3290 | g_loss: 0.3880
# Epoch [    6/   10] | d_loss: 0.3863 | g_loss: 0.5434
# Epoch [    6/   10] | d_loss: 0.3634 | g_loss: 1.0284
# Epoch [    6/   10] | d_loss: 0.3304 | g_loss: 0.4466
# Epoch [    6/   10] | d_loss: 0.3380 | g_loss: 0.6166
# Epoch [    6/   10] | d_loss: 0.3488 | g_loss: 0.3849
# Epoch [    6/   10] | d_loss: 0.3461 | g_loss: 0.3541
# Epoch [    6/   10] | d_loss: 0.3304 | g_loss: 0.5724
# Epoch [    6/   10] | d_loss: 0.3456 | g_loss: 0.3329
# Epoch [    6/   10] | d_loss: 0.3780 | g_loss: 0.3748
# Epoch [    6/   10] | d_loss: 0.3309 | g_loss: 0.4178
# Epoch [    6/   10] | d_loss: 0.3287 | g_loss: 0.5289
# Epoch [    6/   10] | d_loss: 0.3404 | g_loss: 0.4015
# Epoch [    6/   10] | d_loss: 0.3401 | g_loss: 0.3882
# Epoch [    6/   10] | d_loss: 0.3417 | g_loss: 0.6039
# Epoch [    6/   10] | d_loss: 0.3314 | g_loss: 0.4546
# Epoch [    6/   10] | d_loss: 0.3292 | g_loss: 0.6619
# Epoch [    6/   10] | d_loss: 0.3275 | g_loss: 0.6551
# Epoch [    6/   10] | d_loss: 0.3307 | g_loss: 0.5738
# Epoch [    6/   10] | d_loss: 0.3279 | g_loss: 0.3993
# Epoch [    6/   10] | d_loss: 0.3414 | g_loss: 0.3490
# Epoch [    6/   10] | d_loss: 0.3493 | g_loss: 0.3486
# Epoch [    6/   10] | d_loss: 0.3301 | g_loss: 0.3350
# Epoch [    6/   10] | d_loss: 0.3404 | g_loss: 0.3353
# Epoch [    6/   10] | d_loss: 0.3314 | g_loss: 0.3377
# Epoch [    6/   10] | d_loss: 0.3345 | g_loss: 0.3382
# Epoch [    6/   10] | d_loss: 0.3285 | g_loss: 0.3271
# Epoch [    6/   10] | d_loss: 0.3328 | g_loss: 0.3457
# Epoch [    6/   10] | d_loss: 0.3397 | g_loss: 0.3888
# Epoch [    6/   10] | d_loss: 0.3289 | g_loss: 0.4344
# Epoch [    6/   10] | d_loss: 0.3398 | g_loss: 0.3461
# Epoch [    6/   10] | d_loss: 0.3281 | g_loss: 0.3292
# Epoch [    6/   10] | d_loss: 0.3297 | g_loss: 0.4770
# Epoch [    6/   10] | d_loss: 0.3326 | g_loss: 0.3518
# Epoch [    6/   10] | d_loss: 0.3290 | g_loss: 0.3775
# Epoch [    6/   10] | d_loss: 0.3622 | g_loss: 0.4004
# Epoch [    6/   10] | d_loss: 0.3637 | g_loss: 0.3774
# Epoch [    6/   10] | d_loss: 0.3537 | g_loss: 0.3655
# Epoch [    6/   10] | d_loss: 0.4544 | g_loss: 0.4617
# Epoch [    6/   10] | d_loss: 0.3453 | g_loss: 0.4524
# Epoch [    6/   10] | d_loss: 0.3449 | g_loss: 0.7508
# Epoch [    6/   10] | d_loss: 0.3338 | g_loss: 0.7215
# Epoch [    6/   10] | d_loss: 0.3382 | g_loss: 0.5240
# Epoch [    6/   10] | d_loss: 0.3392 | g_loss: 0.3729
# Epoch [    6/   10] | d_loss: 0.3357 | g_loss: 0.4132
# Epoch [    6/   10] | d_loss: 0.3398 | g_loss: 0.4926
# Epoch [    6/   10] | d_loss: 0.3330 | g_loss: 0.8051
# Epoch [    6/   10] | d_loss: 0.3371 | g_loss: 0.3936
# Epoch [    6/   10] | d_loss: 0.3342 | g_loss: 0.6119
# Epoch [    6/   10] | d_loss: 0.3388 | g_loss: 0.3965
# Epoch [    6/   10] | d_loss: 0.4500 | g_loss: 0.4806
# Epoch [    6/   10] | d_loss: 0.3313 | g_loss: 1.2371
# Epoch [    6/   10] | d_loss: 0.3628 | g_loss: 0.8822
# Epoch [    6/   10] | d_loss: 0.4745 | g_loss: 0.3332
# Epoch [    6/   10] | d_loss: 0.3286 | g_loss: 0.3444
# Epoch [    7/   10] | d_loss: 0.4282 | g_loss: 0.3272
# Epoch [    7/   10] | d_loss: 0.3374 | g_loss: 0.3826
# Epoch [    7/   10] | d_loss: 0.3416 | g_loss: 0.3289
# Epoch [    7/   10] | d_loss: 0.3812 | g_loss: 0.4417
# Epoch [    7/   10] | d_loss: 0.3304 | g_loss: 0.3381
# Epoch [    7/   10] | d_loss: 0.3340 | g_loss: 0.3531
# Epoch [    7/   10] | d_loss: 0.3290 | g_loss: 0.3494
# Epoch [    7/   10] | d_loss: 0.3337 | g_loss: 0.3333
# Epoch [    7/   10] | d_loss: 0.4273 | g_loss: 0.3402
# Epoch [    7/   10] | d_loss: 0.3530 | g_loss: 0.3331
# Epoch [    7/   10] | d_loss: 0.3360 | g_loss: 0.3482
# Epoch [    7/   10] | d_loss: 0.3583 | g_loss: 0.4046
# Epoch [    7/   10] | d_loss: 0.3306 | g_loss: 0.7728
# Epoch [    7/   10] | d_loss: 0.3296 | g_loss: 0.6055
# Epoch [    7/   10] | d_loss: 0.3422 | g_loss: 0.4078
# Epoch [    7/   10] | d_loss: 0.3338 | g_loss: 0.3333
# Epoch [    7/   10] | d_loss: 0.3332 | g_loss: 0.4185
# Epoch [    7/   10] | d_loss: 0.4084 | g_loss: 0.3291
# Epoch [    7/   10] | d_loss: 0.3441 | g_loss: 0.3483
# Epoch [    7/   10] | d_loss: 0.3355 | g_loss: 0.6655
# Epoch [    7/   10] | d_loss: 0.3546 | g_loss: 0.4244
# Epoch [    7/   10] | d_loss: 0.3311 | g_loss: 0.6484
# Epoch [    7/   10] | d_loss: 0.3369 | g_loss: 0.3680
# Epoch [    7/   10] | d_loss: 0.3352 | g_loss: 1.0050
# Epoch [    7/   10] | d_loss: 0.3459 | g_loss: 1.2243
# Epoch [    7/   10] | d_loss: 0.3694 | g_loss: 0.6915
# Epoch [    7/   10] | d_loss: 0.3527 | g_loss: 1.5738
# Epoch [    7/   10] | d_loss: 0.3458 | g_loss: 0.7802
# Epoch [    7/   10] | d_loss: 0.3507 | g_loss: 1.2335
# Epoch [    7/   10] | d_loss: 0.3547 | g_loss: 0.4537
# Epoch [    7/   10] | d_loss: 0.3398 | g_loss: 0.4457
# Epoch [    7/   10] | d_loss: 0.3321 | g_loss: 0.5293
# Epoch [    7/   10] | d_loss: 0.3837 | g_loss: 0.3981
# Epoch [    7/   10] | d_loss: 0.3285 | g_loss: 0.6939
# Epoch [    7/   10] | d_loss: 0.3298 | g_loss: 0.3335
# Epoch [    7/   10] | d_loss: 0.3306 | g_loss: 0.3448
# Epoch [    7/   10] | d_loss: 0.3430 | g_loss: 0.3841
# Epoch [    7/   10] | d_loss: 0.3671 | g_loss: 0.5225
# Epoch [    7/   10] | d_loss: 0.3437 | g_loss: 0.3399
# Epoch [    7/   10] | d_loss: 0.3300 | g_loss: 0.8295
# Epoch [    7/   10] | d_loss: 0.3502 | g_loss: 1.3596
# Epoch [    7/   10] | d_loss: 0.3727 | g_loss: 0.8735
# Epoch [    7/   10] | d_loss: 0.3338 | g_loss: 0.3657
# Epoch [    7/   10] | d_loss: 0.3301 | g_loss: 1.0506
# Epoch [    7/   10] | d_loss: 0.3320 | g_loss: 0.7481
# Epoch [    7/   10] | d_loss: 0.4254 | g_loss: 0.3359
# Epoch [    7/   10] | d_loss: 0.3344 | g_loss: 0.3308
# Epoch [    7/   10] | d_loss: 0.3372 | g_loss: 0.3491
# Epoch [    7/   10] | d_loss: 0.3434 | g_loss: 0.3369
# Epoch [    7/   10] | d_loss: 0.5706 | g_loss: 0.3425
# Epoch [    7/   10] | d_loss: 0.4497 | g_loss: 0.3331
# Epoch [    7/   10] | d_loss: 0.3329 | g_loss: 0.4576
# Epoch [    7/   10] | d_loss: 0.3332 | g_loss: 0.5024
# Epoch [    7/   10] | d_loss: 0.3526 | g_loss: 0.3480
# Epoch [    7/   10] | d_loss: 0.3357 | g_loss: 0.3287
# Epoch [    7/   10] | d_loss: 0.3379 | g_loss: 0.3349
# Epoch [    7/   10] | d_loss: 0.3398 | g_loss: 1.1022
# Epoch [    8/   10] | d_loss: 0.3320 | g_loss: 0.3311
# Epoch [    8/   10] | d_loss: 0.3334 | g_loss: 0.4852
# Epoch [    8/   10] | d_loss: 0.3471 | g_loss: 0.3755
# Epoch [    8/   10] | d_loss: 0.3330 | g_loss: 0.3398
# Epoch [    8/   10] | d_loss: 0.4717 | g_loss: 0.3870
# Epoch [    8/   10] | d_loss: 0.3370 | g_loss: 0.3371
# Epoch [    8/   10] | d_loss: 0.3345 | g_loss: 0.3521
# Epoch [    8/   10] | d_loss: 0.3275 | g_loss: 0.5679
# Epoch [    8/   10] | d_loss: 0.3342 | g_loss: 0.3572
# Epoch [    8/   10] | d_loss: 0.3293 | g_loss: 0.3564
# Epoch [    8/   10] | d_loss: 0.4568 | g_loss: 0.3430
# Epoch [    8/   10] | d_loss: 0.3397 | g_loss: 0.4660
# Epoch [    8/   10] | d_loss: 0.3588 | g_loss: 0.3467
# Epoch [    8/   10] | d_loss: 0.3341 | g_loss: 0.3331
# Epoch [    8/   10] | d_loss: 0.3330 | g_loss: 0.4631
# Epoch [    8/   10] | d_loss: 0.3558 | g_loss: 0.5070
# Epoch [    8/   10] | d_loss: 0.3698 | g_loss: 0.9368
# Epoch [    8/   10] | d_loss: 0.3615 | g_loss: 0.5268
# Epoch [    8/   10] | d_loss: 0.3360 | g_loss: 0.3597
# Epoch [    8/   10] | d_loss: 0.3300 | g_loss: 0.4880
# Epoch [    8/   10] | d_loss: 0.3288 | g_loss: 0.3577
# Epoch [    8/   10] | d_loss: 0.3323 | g_loss: 0.3316
# Epoch [    8/   10] | d_loss: 0.3307 | g_loss: 0.7476
# Epoch [    8/   10] | d_loss: 0.3313 | g_loss: 0.3323
# Epoch [    8/   10] | d_loss: 0.3469 | g_loss: 0.3310
# Epoch [    8/   10] | d_loss: 0.3340 | g_loss: 0.3402
# Epoch [    8/   10] | d_loss: 0.3570 | g_loss: 0.3294
# Epoch [    8/   10] | d_loss: 0.3876 | g_loss: 0.3418
# Epoch [    8/   10] | d_loss: 0.3301 | g_loss: 0.3330
# Epoch [    8/   10] | d_loss: 0.3390 | g_loss: 0.3731
# Epoch [    8/   10] | d_loss: 0.3313 | g_loss: 0.3613
# Epoch [    8/   10] | d_loss: 0.3344 | g_loss: 0.3371
# Epoch [    8/   10] | d_loss: 0.3330 | g_loss: 0.7540
# Epoch [    8/   10] | d_loss: 0.3312 | g_loss: 0.3279
# Epoch [    8/   10] | d_loss: 0.3300 | g_loss: 0.3504
# Epoch [    8/   10] | d_loss: 0.3284 | g_loss: 0.3915
# Epoch [    8/   10] | d_loss: 0.3382 | g_loss: 0.3315
# Epoch [    8/   10] | d_loss: 0.3330 | g_loss: 0.3381
# Epoch [    8/   10] | d_loss: 0.3321 | g_loss: 0.4928
# Epoch [    8/   10] | d_loss: 0.3414 | g_loss: 0.4541
# Epoch [    8/   10] | d_loss: 0.3342 | g_loss: 0.3345
# Epoch [    8/   10] | d_loss: 0.3303 | g_loss: 0.3925
# Epoch [    8/   10] | d_loss: 0.3431 | g_loss: 0.3319
# Epoch [    8/   10] | d_loss: 0.3310 | g_loss: 0.3358
# Epoch [    8/   10] | d_loss: 0.3339 | g_loss: 0.5283
# Epoch [    8/   10] | d_loss: 0.3510 | g_loss: 0.4083
# Epoch [    8/   10] | d_loss: 0.3331 | g_loss: 0.3322
# Epoch [    8/   10] | d_loss: 0.3299 | g_loss: 0.3401
# Epoch [    8/   10] | d_loss: 0.3371 | g_loss: 0.3291
# Epoch [    8/   10] | d_loss: 0.3425 | g_loss: 0.3724
# Epoch [    8/   10] | d_loss: 0.3342 | g_loss: 0.3495
# Epoch [    8/   10] | d_loss: 0.3435 | g_loss: 0.3295
# Epoch [    8/   10] | d_loss: 0.3286 | g_loss: 0.3794
# Epoch [    8/   10] | d_loss: 0.3289 | g_loss: 0.3743
# Epoch [    8/   10] | d_loss: 0.3300 | g_loss: 0.3705
# Epoch [    8/   10] | d_loss: 0.3440 | g_loss: 0.3428
# Epoch [    8/   10] | d_loss: 0.3355 | g_loss: 0.3291
# Epoch [    9/   10] | d_loss: 0.3342 | g_loss: 0.3353
# Epoch [    9/   10] | d_loss: 0.3376 | g_loss: 0.3305
# Epoch [    9/   10] | d_loss: 0.3290 | g_loss: 0.4572
# Epoch [    9/   10] | d_loss: 0.3313 | g_loss: 0.4130
# Epoch [    9/   10] | d_loss: 0.3321 | g_loss: 0.4025
# Epoch [    9/   10] | d_loss: 0.3288 | g_loss: 0.5124
# Epoch [    9/   10] | d_loss: 0.3473 | g_loss: 0.3457
# Epoch [    9/   10] | d_loss: 0.3268 | g_loss: 0.4468
# Epoch [    9/   10] | d_loss: 0.3278 | g_loss: 1.1836
# Epoch [    9/   10] | d_loss: 0.3290 | g_loss: 0.3337
# Epoch [    9/   10] | d_loss: 0.3331 | g_loss: 0.3270
# Epoch [    9/   10] | d_loss: 0.3335 | g_loss: 0.3493
# Epoch [    9/   10] | d_loss: 0.3498 | g_loss: 0.3487
# Epoch [    9/   10] | d_loss: 0.3474 | g_loss: 0.3300
# Epoch [    9/   10] | d_loss: 0.3297 | g_loss: 0.3283
# Epoch [    9/   10] | d_loss: 0.3355 | g_loss: 0.3361
# Epoch [    9/   10] | d_loss: 0.3335 | g_loss: 0.3282
# Epoch [    9/   10] | d_loss: 0.3283 | g_loss: 0.3515
# Epoch [    9/   10] | d_loss: 0.3277 | g_loss: 0.4152
# Epoch [    9/   10] | d_loss: 0.3331 | g_loss: 0.3360
# Epoch [    9/   10] | d_loss: 0.3388 | g_loss: 0.3269
# Epoch [    9/   10] | d_loss: 0.3326 | g_loss: 0.3292
# Epoch [    9/   10] | d_loss: 0.3286 | g_loss: 0.3308
# Epoch [    9/   10] | d_loss: 0.3285 | g_loss: 0.3366
# Epoch [    9/   10] | d_loss: 0.3266 | g_loss: 0.3408
# Epoch [    9/   10] | d_loss: 0.3355 | g_loss: 0.3333
# Epoch [    9/   10] | d_loss: 0.3317 | g_loss: 0.4444
# Epoch [    9/   10] | d_loss: 0.3264 | g_loss: 0.3704
# Epoch [    9/   10] | d_loss: 0.3347 | g_loss: 0.3324
# Epoch [    9/   10] | d_loss: 0.3275 | g_loss: 0.3392
# Epoch [    9/   10] | d_loss: 0.3280 | g_loss: 0.3315
# Epoch [    9/   10] | d_loss: 0.3261 | g_loss: 0.3347
# Epoch [    9/   10] | d_loss: 0.3293 | g_loss: 0.3295
# Epoch [    9/   10] | d_loss: 0.3260 | g_loss: 0.3334
# Epoch [    9/   10] | d_loss: 0.3261 | g_loss: 0.4478
# Epoch [    9/   10] | d_loss: 0.3269 | g_loss: 0.3340
# Epoch [    9/   10] | d_loss: 0.3270 | g_loss: 0.3320
# Epoch [    9/   10] | d_loss: 0.3264 | g_loss: 0.3674
# Epoch [    9/   10] | d_loss: 0.3288 | g_loss: 0.3278
# Epoch [    9/   10] | d_loss: 0.3262 | g_loss: 0.3596
# Epoch [    9/   10] | d_loss: 0.3311 | g_loss: 0.3309
# Epoch [    9/   10] | d_loss: 0.3266 | g_loss: 0.3273
# Epoch [    9/   10] | d_loss: 0.3267 | g_loss: 0.3286
# Epoch [    9/   10] | d_loss: 0.3257 | g_loss: 0.3314
# Epoch [    9/   10] | d_loss: 0.3267 | g_loss: 0.3318
# Epoch [    9/   10] | d_loss: 0.3262 | g_loss: 0.3277
# Epoch [    9/   10] | d_loss: 0.3254 | g_loss: 0.3344
# Epoch [    9/   10] | d_loss: 0.3259 | g_loss: 0.3290
# Epoch [    9/   10] | d_loss: 0.3258 | g_loss: 0.3328
# Epoch [    9/   10] | d_loss: 0.3258 | g_loss: 0.3288
# Epoch [    9/   10] | d_loss: 0.3255 | g_loss: 0.3313
# Epoch [    9/   10] | d_loss: 0.3257 | g_loss: 0.3493
# Epoch [    9/   10] | d_loss: 0.3262 | g_loss: 0.3397
# Epoch [    9/   10] | d_loss: 0.3258 | g_loss: 0.3255
# Epoch [    9/   10] | d_loss: 0.3275 | g_loss: 0.3291
# Epoch [    9/   10] | d_loss: 0.3260 | g_loss: 0.3256
# Epoch [    9/   10] | d_loss: 0.3256 | g_loss: 0.3269
# Epoch [   10/   10] | d_loss: 0.3255 | g_loss: 0.3258
# Epoch [   10/   10] | d_loss: 0.3257 | g_loss: 0.3307
# Epoch [   10/   10] | d_loss: 0.3270 | g_loss: 0.3277
# Epoch [   10/   10] | d_loss: 0.3265 | g_loss: 0.3289
# Epoch [   10/   10] | d_loss: 0.3258 | g_loss: 0.3297
# Epoch [   10/   10] | d_loss: 0.3257 | g_loss: 0.3265
# Epoch [   10/   10] | d_loss: 0.3257 | g_loss: 0.3293
# Epoch [   10/   10] | d_loss: 0.3262 | g_loss: 0.3295
# Epoch [   10/   10] | d_loss: 0.3257 | g_loss: 0.3263
# Epoch [   10/   10] | d_loss: 0.3259 | g_loss: 0.3270
# Epoch [   10/   10] | d_loss: 0.3254 | g_loss: 0.3260
# Epoch [   10/   10] | d_loss: 0.3254 | g_loss: 0.3633
# Epoch [   10/   10] | d_loss: 0.3255 | g_loss: 0.3405
# Epoch [   10/   10] | d_loss: 0.3254 | g_loss: 0.3281
# Epoch [   10/   10] | d_loss: 0.3254 | g_loss: 0.3356
# Epoch [   10/   10] | d_loss: 0.3256 | g_loss: 0.3884
# Epoch [   10/   10] | d_loss: 0.3262 | g_loss: 0.3453
# Epoch [   10/   10] | d_loss: 0.3254 | g_loss: 0.3644
# Epoch [   10/   10] | d_loss: 0.3257 | g_loss: 0.4912
# Epoch [   10/   10] | d_loss: 0.3261 | g_loss: 0.4857
# Epoch [   10/   10] | d_loss: 0.3254 | g_loss: 0.3595
# Epoch [   10/   10] | d_loss: 0.3257 | g_loss: 0.3333
# Epoch [   10/   10] | d_loss: 0.3254 | g_loss: 0.3279
# Epoch [   10/   10] | d_loss: 0.3253 | g_loss: 0.3262
# Epoch [   10/   10] | d_loss: 0.3264 | g_loss: 0.3749
# Epoch [   10/   10] | d_loss: 0.3253 | g_loss: 0.3377
# Epoch [   10/   10] | d_loss: 0.3252 | g_loss: 0.3276
# Epoch [   10/   10] | d_loss: 0.3261 | g_loss: 0.3308
# Epoch [   10/   10] | d_loss: 0.3253 | g_loss: 0.3274
# Epoch [   10/   10] | d_loss: 0.3256 | g_loss: 0.3266
# Epoch [   10/   10] | d_loss: 0.3261 | g_loss: 0.3388
# Epoch [   10/   10] | d_loss: 0.3265 | g_loss: 0.3298
# Epoch [   10/   10] | d_loss: 0.3257 | g_loss: 0.3314
# Epoch [   10/   10] | d_loss: 0.3254 | g_loss: 0.3324
# Epoch [   10/   10] | d_loss: 0.3255 | g_loss: 0.3276
# Epoch [   10/   10] | d_loss: 0.3254 | g_loss: 0.3257
# Epoch [   10/   10] | d_loss: 0.3255 | g_loss: 0.3261
# Epoch [   10/   10] | d_loss: 0.3255 | g_loss: 0.3425
# Epoch [   10/   10] | d_loss: 0.3252 | g_loss: 0.3269
# Epoch [   10/   10] | d_loss: 0.3253 | g_loss: 0.3308
# Epoch [   10/   10] | d_loss: 0.3257 | g_loss: 0.3259
# Epoch [   10/   10] | d_loss: 0.3252 | g_loss: 0.3275
# Epoch [   10/   10] | d_loss: 0.3253 | g_loss: 0.3254
# Epoch [   10/   10] | d_loss: 0.3254 | g_loss: 0.3255
# Epoch [   10/   10] | d_loss: 0.3253 | g_loss: 0.3259
# Epoch [   10/   10] | d_loss: 0.3254 | g_loss: 0.3261
# Epoch [   10/   10] | d_loss: 0.3254 | g_loss: 0.3275
# Epoch [   10/   10] | d_loss: 0.3253 | g_loss: 0.3386
# Epoch [   10/   10] | d_loss: 0.3260 | g_loss: 0.3256
# Epoch [   10/   10] | d_loss: 0.3259 | g_loss: 0.3278
# Epoch [   10/   10] | d_loss: 0.3254 | g_loss: 0.3353
# Epoch [   10/   10] | d_loss: 0.3254 | g_loss: 0.4060
# Epoch [   10/   10] | d_loss: 0.3254 | g_loss: 0.3428
# Epoch [   10/   10] | d_loss: 0.3258 | g_loss: 0.3363
# Epoch [   10/   10] | d_loss: 0.3257 | g_loss: 0.3347
# Epoch [   10/   10] | d_loss: 0.3255 | g_loss: 0.3384
# Epoch [   10/   10] | d_loss: 0.3254 | g_loss: 2.3425

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:** (Write your answer in this cell)

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
